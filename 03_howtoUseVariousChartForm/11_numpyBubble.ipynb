# %% [markdown]
# # 201701058_김태헌_#13_numpyBubble.ipynb
# numpy 라이브러리를 이용해 bubblechart 를 생성한다.

# %%
import matplotlib.pyplot as plt
import random

x=[]
y=[]
size=[]

for i in range(200):
    x.append(random.randint(10,100))
    y.append(random.randint(10,100))
    size.append(random.randint(10,100))
    
plt.scatter(x,y,s=size , c =x , cmap='jet', alpha=0.7)
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.random.randint(10,100,200)
y=np.random.randint(10,100,200)
size=np.random.rand(200) *100

plt.scatter(x,y,s=size, c=x, cmap='jet', alpha=0.7)
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
a=np.arange(-np.pi, np.pi, np.pi/100)
plt.plot(a,np.sin(a))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
a=np.arange(-np.pi, np.pi, np.pi/100)
plt.plot(a,np.sin(a))
plt.plot(a,np.cos(a))
plt.plot(a+np.pi/2,np.sin(a))
plt.show()

# %%
import numpy as np
a = np.arange(-5,5)
print(a)

print(a<0)

print(a[a<0])

mask1=abs(a)>3 #mask1를 통해 일부 데이터만 추출

print(a[mask1])
# Out:
# [-5 -4 -3 -2 -1  0  1  2  3  4]
# [ True  True  True  True  True False False False False False]
# [-5 -4 -3 -2 -1]
# [-5 -4  4]

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.random.randint(10,100,200)
y=np.random.randint(10,100,200)
size=np.random.rand(200) *100

plt.scatter(x,y,s=size, c=x, cmap='jet', alpha=0.7)
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.randint(-100,100,1000)
y=np.random.randint(-100,100,1000)



mask1=abs(x)>50 # x좌표의 절대값 >50
mask2=abs(y)>50 # y좌표의 절대값 >50

x=x[mask1+mask2]
y=y[mask1+mask2]

size=np.random.rand(x.size)  * 100




plt.title('Bubble Chart - numpy library')
plt.scatter(x,y,s=size, c=x, cmap='jet', alpha=0.7)
plt.colorbar()
plt.savefig('BubbleChart_numpyLibrary'+'.png',bbox_inches='tight') # 파일 저장
plt.show()
