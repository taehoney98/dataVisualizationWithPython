# %% [markdown]
# # 남녀 인구 분포 출력
#
# gender.csv에 저장된 남녀 인구 분포를 plot 형식을 통해 그래프로 표현한다.

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
m=[]
f=[]
name=input('지역명 입력:')
for row in data:
    if name in row[0]:
        for i in range(3,104):
            m.append(int(row[i].replace("," , "")))
            f.append(int(row[i+103].replace("," , "")))
        break
    
import matplotlib.pyplot as plt

plt.plot(m, label='Male')
plt.plot(f, label='Female')
plt.legend()
plt.show()

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
m = []
f = []
province= input('도 이름을 입력하세요 ')
country = input('구 이름을 입력하세요 ')
name  = input('읍면동 단위를 입력하세요 ')

for row in data:
    if  (province and country and name )in row[0]:
        for i in row [3:104]:
            m.append(-int(i.replace(',', '')))
        for i in row [106: ]:
            f.append(int(i.replace(',', '')))
        break
            
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(10 , 5) , dpi =300)

plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus']= False

plt.title('Apr_2020_population_' +province + country + name + 'plotChart')
plt.xlabel('남성인구')
plt.ylabel('여성인구')
            #pyramid함수로는 원하는 정보 얻기 어렵다
plt.plot( range(101), m , color= 'blue', label = 'male' )         
plt.plot(range(101), f , color= 'hotpink', label = 'female')
plt.legend() 
plt.show()

# %% [markdown]
# ## 남녀 인구수 차이를 bar Chart로 표현

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
result=[]
name=input('지역명 입력:')
for row in data:
    if name in row[0]:
        for i in range(3,104):
            result.append(int(row[i].replace("," , ""))-int(row[i+103].replace("," , "")))
        break
    
import matplotlib.pyplot as plt

plt.bar(range(101),result)
plt.show()

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
result=[]
name= input('지역명을 입력하세요 ')

for row in data:
    if  name in row[0]:
        for i in range (3,104):
            result.append(int(row[i].replace(',', '')) -int(row[i+103].replace(',', '')))
        break
        
import matplotlib.pyplot as plt

plt.rc('font', family = 'Malgun Gothic')
plt.title("남녀 인구수 차이")
plt.plot(result, label='male - female')

plt.legend()
plt.show()
